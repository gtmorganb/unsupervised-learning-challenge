# %%
# Initial imports
import pandas as pd
from pathlib import Path

# %%
 # Data loading
file_path = Path("crypto_data.csv")
crypto_df = pd.read_csv(file_path)
crypto_df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %%
crypto_rows = len(crypto_df)
crypto_rows
# Out:
# 1252

# %%
#drop non-trading currencies
crypto_trade = crypto_df[crypto_df['IsTrading'] != 0]
crypto_trade
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 1           365      365Coin          X11       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 3           611    SixEleven      SHA-256       True       PoW
# 4           808          808      SHA-256       True   PoW/PoS
# ...         ...          ...          ...        ...       ...
# 1243       SERO   Super Zero       Ethash       True       PoW
# 1244        UOS          UOS      SHA-256       True      DPoI
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
#drop IsTrading from dataset 
crypto_new = crypto_trade.drop(['IsTrading'], axis = 1)
crypto_new
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 1           365      365Coin          X11   PoW/PoS              NaN
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 3           611    SixEleven      SHA-256       PoW              NaN
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# ...         ...          ...          ...       ...              ...
# 1243       SERO   Super Zero       Ethash       PoW              NaN
# 1244        UOS          UOS      SHA-256      DPoI              NaN
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %%
#dropping rows with NaN
crypto_clean = crypto_new.dropna(axis=0, how='any')
crypto_clean
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 4                  0
# 5       314159265359
# 7           21000000
# ...

# %%
#finding mined values greater than 0 
crypto_cleaned = crypto_clean[crypto_clean['TotalCoinsMined'] > 0]
crypto_cleaned
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# 8           ETH     Ethereum       Ethash       PoW     1.076842e+08
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...

# %%
#remove Coin Name from dataframe
crypto_next = crypto_cleaned.drop(['CoinName'], axis = 1)
crypto_next
# Out:
#      Unnamed: 0    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0            42       Scrypt   PoW/PoS     4.199995e+01              42
# 2           404       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5          1337          X13   PoW/PoS     2.927942e+10    314159265359
# 7           BTC      SHA-256       PoW     1.792718e+07        21000000
# 8           ETH       Ethash       PoW     1.076842e+08               0
# ...         ...          ...       ...              ...             ...
# 1238       ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# 1242        GAP       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245        BDX  CryptoNight       PoW     9.802226e+08      1400222610
# 1246        ZEN     Equihash       PoW     7.296538e+06        21000000
# 1247        XBC       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
#renaming columns and setting index
crypto_next.columns = ['CryptoID', 'Algorithm', 'ProofType', 'TotalCoinsMined', 'TotalCoinSupply']

crypt_final =crypto_next.set_index("CryptoID")
crypt_final
# Out:
#             Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# CryptoID
# 42             Scrypt   PoW/PoS     4.199995e+01              42
# 404            Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337              X13   PoW/PoS     2.927942e+10    314159265359
# BTC           SHA-256       PoW     1.792718e+07        21000000
# ETH            Ethash       PoW     1.076842e+08               0
# ...               ...       ...              ...             ...
# ZEPH          SHA-256      DPoS     2.000000e+09      2000000000
# GAP            Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX       CryptoNight       PoW     9.802226e+08      1400222610
# ZEN          Equihash       PoW     7.296538e+06        21000000
# XBC            Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
#changing Total Coin Supply to float before get dummies since it is numerical 
crypt_final["TotalCoinSupply"] = crypt_final.TotalCoinSupply.astype(float)
list(crypt_final.dtypes)
# Out:
# [dtype('O'), dtype('O'), dtype('float64'), dtype('float64')]

# %%
crypto_dum = pd.get_dummies(crypt_final)
crypto_dum
# Out:
#           TotalCoinsMined  TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# CryptoID
# 42           4.199995e+01     4.200000e+01                                 0
# 404          1.055185e+09     5.320000e+08                                 0
# 1337         2.927942e+10     3.141593e+11                                 0
# BTC          1.792718e+07     2.100000e+07                                 0
# ETH          1.076842e+08     0.000000e+00                                 0
# ...                   ...              ...                               ...
# ZEPH         2.000000e+09     2.000000e+09                                 0
# GAP          1.493105e+07     2.500000e+08                                 0
# BDX          9.802226e+08     1.400223e+09                                 0
# ZEN          7.296538e+06     2.100000e+07                                 0
# XBC          1.283270e+05     1.000000e+06                                 0
#
# ...

# %%
#additional imports for dummy variables and standardizing data
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
scaler = StandardScaler()
crypto_scale = scaler.fit_transform(crypto_dum)
crypto_scale
# Out:
# array([[-0.11710817, -0.1528703 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.145009  , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [ 0.52494561,  4.48942416, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        ...,
#        [-0.09561336, -0.13217937, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11694817, -0.15255998, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11710536, -0.15285552, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ]])

# %% [markdown]
# # Dimensionality Reduction

# %%
pca = PCA(n_components=0.9)

# %%
crypto_pca = pca.fit_transform(crypto_scale)

# %%
 # Transform PCA data to a DataFrame
pca_df = pd.DataFrame(data=crypto_pca)
pca_df
# Out:
#            0         1         2         3             4             5   \
# 0   -0.335099  1.032189 -0.590713  0.001397  8.903525e-15  3.715567e-12
# 1   -0.318434  1.032331 -0.591126  0.001386  8.797456e-15  3.685202e-12
# 2    2.305468  1.656383 -0.683617  0.004731  1.292867e-14  1.259214e-11
# 3   -0.145184 -1.320593  0.192813 -0.001229 -2.452485e-15 -3.268574e-12
# 4   -0.151768 -2.036192  0.396182 -0.001705 -1.119309e-14 -4.534708e-12
# ..        ...       ...       ...       ...           ...           ...
# 527  2.471251  0.822241 -0.071160 -0.008206  5.053451e-15 -2.187479e-11
# 528 -0.333144  1.032071 -0.590740  0.001399  8.834849e-15  3.721725e-12
# 529  0.324349 -2.312308  0.421515 -0.001319 -5.674971e-15 -3.506871e-12
# 530 -0.149364 -2.049336  0.412968 -0.001745 -6.510239e-15 -4.640471e-12
# 531 -0.289957  0.821195 -0.276327  0.000555  4.112527e-15  1.475630e-12
#
#                6         7         8         9   ...            64  \
# ...

# %%
 # Fetch the explained variance
pca.explained_variance_ratio_
# Out:
# array([0.0279317 , 0.02141802, 0.02051615, 0.02044661, 0.0204466 ,
#        0.0204466 , 0.0204466 , 0.02042554, 0.01870913, 0.01756291,
#        0.01741106, 0.01629007, 0.01596154, 0.01551138, 0.01435005,
#        0.01321122, 0.01236583, 0.01206255, 0.01104295, 0.01071499,
#        0.01049079, 0.01040887, 0.01039089, 0.01037741, 0.01035414,
#        0.01034034, 0.01029605, 0.01028233, 0.01028139, 0.01028139,
#        0.01028138, 0.01027965, 0.01027051, 0.01026331, 0.01026202,
#        0.01025761, 0.01025565, 0.01025068, 0.01024924, 0.01024279,
#        0.01024259, 0.01024259, 0.0102419 , 0.01024018, 0.01023676,
#        0.01023495, 0.01023   , 0.01022442, 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
# ...

# %%
#more dependencies
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
#tSNE on pca data
tsne = TSNE(learning_rate=100)
transformed_features = tsne.fit_transform(crypto_pca)

# %%
 # Check that dimensions have been reduced to two
transformed_features.shape
# Out:
# (532, 2)

# %%
crypto_dum['x'] = transformed_features[:,0]
crypto_dum['y'] = transformed_features[:,1]

# %%
plt.scatter(crypto_dum['x'], crypto_dum['y'])
plt.show()

# %% [markdown]
# # Cluster Analysis with k-Means

# %%
#Define the inertia and K cluster
inertia = []
k = list(range(1, 10)) 

# Calculate the inertia for the range of K values
for i in k:
   km = KMeans(n_clusters=i, random_state=0)
   km.fit(pca_df)
   inertia.append(km.inertia_)
# Out:
# C:\Users\gtmor\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()
# Out:
#    k       inertia
# 0  1  46979.075160
# 1  2  45909.857193
# 2  3  44845.490039
# 3  4  43778.700400
# 4  5  42518.641991

# %%
 # Plot the elbow curve to find the best candidate(s) for k
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for customer data')
plt.show()

# %%
def get_clusters(k, data):
    # Initialize the K-Means model
    model = KMeans(n_clusters=k, random_state=0)

    # Train the model
    model.fit(data)

    # Predict clusters
    predictions = model.predict(data)

    # Create return DataFrame with predicted clusters
    data["class"] = model.labels_

    return data

# %%
clusters = get_clusters(6, crypto_dum)
clusters
# Out:
#           TotalCoinsMined  TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# CryptoID
# 42           4.199995e+01     4.200000e+01                                 0
# 404          1.055185e+09     5.320000e+08                                 0
# 1337         2.927942e+10     3.141593e+11                                 0
# BTC          1.792718e+07     2.100000e+07                                 0
# ETH          1.076842e+08     0.000000e+00                                 0
# ...                   ...              ...                               ...
# ZEPH         2.000000e+09     2.000000e+09                                 0
# GAP          1.493105e+07     2.500000e+08                                 0
# BDX          9.802226e+08     1.400223e+09                                 0
# ZEN          7.296538e+06     2.100000e+07                                 0
# XBC          1.283270e+05     1.000000e+06                                 0
#
# ...

# %%
 def show_clusters(df):
    plt.scatter(x=crypto_dum['TotalCoinsMined'],  y=crypto_dum['TotalCoinSupply'])
    plt.xlabel('Mined')
    plt.ylabel('Supply')
    plt.show()

# %%
 show_clusters(clusters)
